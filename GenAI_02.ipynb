# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A52455/GenAI/blob/main/GenAI_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **QUESTION_1**

# %% [markdown]
# ![WhatsApp Image 2025-01-10 at 14.43.05_c2e93a26.jpg](data:image/jpeg;base64,...)

# %%
from scipy.optimize import linprog
import math as mt
import numpy as np

# %%
obj1 = [-6,-5]
A1 = [[1,1],[3,2]]
B1 = [5,12]
bnd = [(0,float("inf")),(0,float("inf"))]
opt = linprog(c=obj1,A_ub=A1,b_ub=B1,bounds=bnd)
choc=np.round(opt.x)
print(f"No. of A : {int(choc[0])}")
print(f"No. of B : {int(choc[1])}")
# Out:
# No. of A : 2
# No. of B : 3

# %% [markdown]
# **QUESTION-2**

# %% [markdown]
# ![WhatsApp Image 2025-01-10 at 14.47.09_ddb17cde.jpg](data:image/jpeg;base64,...)

# %%
obj2 = [-50,-120]
A2 = [[7000,2000],[10,30]]
B2 = [700000,1200]
A = [[1,1]]
B = [100]
bnd = [(0,float("inf")),(0,float("inf"))]
opt = linprog(c=obj2,A_ub=A2,b_ub=B2,A_eq=A, b_eq=B,bounds=bnd, method = 'simplex')
Hex = np.round(opt.x)
print(f"No. of hectares for Wheat : {int(Hex[0])}")
print(f"No. of hectares for Barley : {int(Hex[1])}")
# Out:
# No. of hectares for Wheat : 90
# No. of hectares for Barley : 10
# <ipython-input-9-62f902a57ea5>:7: DeprecationWarning: `method='simplex'` is deprecated and will be removed in SciPy 1.11.0. Please use one of the HiGHS solvers (e.g. `method='highs'`) in new code.
#   opt = linprog(c=obj2,A_ub=A2,b_ub=B2,A_eq=A, b_eq=B,bounds=bnd, method = 'simplex')
